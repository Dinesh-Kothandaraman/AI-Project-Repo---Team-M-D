# %%
import numpy as np
import tensorflow as tf
import cv2
import os
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from collections import deque
from moviepy.editor import VideoFileClip

# %%
# Constants
DATASET_DIR = r"C:\Users\dines\Downloads\AI Project\UCF50\UCF50"
CLASSES_LIST = ["Biking", "Punch", "Diving"]
IMAGE_HEIGHT, IMAGE_WIDTH = 64, 64
SEQUENCE_LENGTH = 20

def frames_extraction(video_path):
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    skip_frames_window = max(int(video_frames_count / SEQUENCE_LENGTH), 1)
    for frame_counter in range(SEQUENCE_LENGTH):
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
        success, frame = video_reader.read()
        if not success:
            break
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        normalized_frame = resized_frame / 255
        frames_list.append(normalized_frame)
    video_reader.release()
    return frames_list

def create_dataset():
    features = []
    labels = []
    video_files_paths = []
    for class_index, class_name in enumerate(CLASSES_LIST):
        print(f'Extracting Data of Class: {class_name}')
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        for file_name in files_list:
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)
            frames = frames_extraction(video_file_path)
            if len(frames) == SEQUENCE_LENGTH:
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)
    features = np.asarray(features)
    labels = np.array(labels)
    return features, labels, video_files_paths

features, labels, video_files_paths = create_dataset()

one_hot_encoded_labels = to_categorical(labels)
num_samples = len(features)
test_size = max(0.25, 1 / num_samples)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    features, one_hot_encoded_labels, test_size=test_size, random_state=42)

# %%
def create_cnn_model():
    model = Sequential()
    model.add(Conv3D(32, (3, 3, 3), activation='relu', input_shape=(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    model.add(MaxPooling3D((1, 2, 2)))  # Adjusted kernel size
    model.add(Dropout(0.25))
    model.add(Conv3D(64, (3, 3, 3), activation='relu'))
    model.add(MaxPooling3D((1, 2, 2)))  # Adjusted kernel size
    model.add(Dropout(0.25))
    model.add(Conv3D(128, (3, 3, 3), activation='relu'))
    model.add(MaxPooling3D((1, 2, 2)))  # Adjusted kernel size
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(len(CLASSES_LIST), activation='softmax'))
    model.summary()
    return model

cnn_model = create_cnn_model()
# early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, mode='min', restore_best_weights=True)
cnn_model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=["accuracy"])
cnn_model_training_history = cnn_model.fit(x=X_train, y=y_train, epochs=50, batch_size=4,
                                           shuffle=True, validation_split=0.2)
                                           

model_evaluation_history = cnn_model.evaluate(X_test, y_test)
# Calculate additional metrics
y_pred = cnn_model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

accuracy = accuracy_score(y_true_classes, y_pred_classes)
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')

# Print the evaluation metrics
print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1-Score: {f1:.4f}')
cnn_model.save('cnn_model.keras')
# Out:
# Extracting Data of Class: Biking
# Extracting Data of Class: Punch
# Extracting Data of Class: Diving
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv3d_3 (Conv3D)                    │ (None, 18, 62, 62, 32)      │           2,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_3 (MaxPooling3D)       │ (None, 18, 31, 31, 32)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 18, 31, 31, 32)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_4 (Conv3D)                    │ (None, 16, 29, 29, 64)      │          55,360 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_4 (MaxPooling3D)       │ (None, 16, 14, 14, 64)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 16, 14, 14, 64)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_5 (Conv3D)                    │ (None, 14, 12, 12, 128)     │         221,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_5 (MaxPooling3D)       │ (None, 14, 6, 6, 128)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 14, 6, 6, 128)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 64512)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 64)                  │       4,128,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,408,323 (16.82 MB)
#  Trainable params: 4,408,323 (16.82 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 34s 431ms/step - accuracy: 0.3621 - loss: 1.3965 - val_accuracy: 0.5362 - val_loss: 1.0244
# Epoch 2/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 29s 423ms/step - accuracy: 0.5378 - loss: 0.8682 - val_accuracy: 0.5507 - val_loss: 0.9481
# Epoch 3/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 427ms/step - accuracy: 0.6394 - loss: 0.8542 - val_accuracy: 0.6377 - val_loss: 0.9197
# Epoch 4/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 31s 445ms/step - accuracy: 0.6906 - loss: 0.7535 - val_accuracy: 0.6232 - val_loss: 1.0989
# Epoch 5/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 430ms/step - accuracy: 0.6330 - loss: 0.8850 - val_accuracy: 0.4928 - val_loss: 0.9622
# Epoch 6/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 428ms/step - accuracy: 0.4758 - loss: 0.9807 - val_accuracy: 0.4203 - val_loss: 1.0722
# Epoch 7/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 41s 419ms/step - accuracy: 0.3906 - loss: 1.0277 - val_accuracy: 0.4638 - val_loss: 1.0709
# Epoch 8/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 436ms/step - accuracy: 0.4732 - loss: 1.0190 - val_accuracy: 0.4783 - val_loss: 1.1656
# Epoch 9/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 29s 422ms/step - accuracy: 0.5258 - loss: 0.9268 - val_accuracy: 0.4783 - val_loss: 1.0939
# Epoch 10/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 29s 426ms/step - accuracy: 0.5036 - loss: 0.9059 - val_accuracy: 0.4928 - val_loss: 1.2325
# Epoch 11/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 428ms/step - accuracy: 0.4970 - loss: 0.8896 - val_accuracy: 0.5072 - val_loss: 1.5129
# Epoch 12/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 431ms/step - accuracy: 0.6270 - loss: 0.8118 - val_accuracy: 0.5942 - val_loss: 3.6265
# Epoch 13/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 31s 442ms/step - accuracy: 0.6619 - loss: 0.8738 - val_accuracy: 0.4203 - val_loss: 1.0511
# Epoch 14/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 430ms/step - accuracy: 0.4170 - loss: 1.0959 - val_accuracy: 0.4783 - val_loss: 1.2768
# Epoch 15/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 438ms/step - accuracy: 0.4978 - loss: 0.9097 - val_accuracy: 0.4783 - val_loss: 1.0550
# Epoch 16/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 29s 426ms/step - accuracy: 0.4415 - loss: 0.9305 - val_accuracy: 0.4928 - val_loss: 1.2632
# Epoch 17/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 434ms/step - accuracy: 0.5548 - loss: 0.8733 - val_accuracy: 0.4928 - val_loss: 1.1745
# Epoch 18/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 429ms/step - accuracy: 0.5777 - loss: 0.8340 - val_accuracy: 0.5217 - val_loss: 1.3820
# Epoch 19/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 429ms/step - accuracy: 0.5055 - loss: 0.9166 - val_accuracy: 0.5072 - val_loss: 1.3363
# Epoch 20/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 29s 426ms/step - accuracy: 0.5549 - loss: 0.9079 - val_accuracy: 0.4493 - val_loss: 1.0961
# Epoch 21/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 75s 930ms/step - accuracy: 0.4155 - loss: 1.0120 - val_accuracy: 0.4493 - val_loss: 1.0654
# Epoch 22/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 432ms/step - accuracy: 0.5154 - loss: 0.9056 - val_accuracy: 0.6232 - val_loss: 3.1148
# Epoch 23/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 57s 827ms/step - accuracy: 0.6381 - loss: 0.8219 - val_accuracy: 0.5652 - val_loss: 2.0902
# Epoch 24/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 25s 364ms/step - accuracy: 0.5219 - loss: 0.9676 - val_accuracy: 0.4928 - val_loss: 1.3733
# Epoch 25/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 29s 426ms/step - accuracy: 0.5356 - loss: 1.4333 - val_accuracy: 0.4348 - val_loss: 1.0052
# Epoch 26/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 429ms/step - accuracy: 0.4165 - loss: 0.9893 - val_accuracy: 0.5507 - val_loss: 1.3451
# Epoch 27/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 429ms/step - accuracy: 0.5113 - loss: 0.9645 - val_accuracy: 0.5362 - val_loss: 1.3102
# Epoch 28/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 439ms/step - accuracy: 0.5722 - loss: 0.8227 - val_accuracy: 0.5072 - val_loss: 1.2885
# Epoch 29/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 437ms/step - accuracy: 0.5609 - loss: 0.8225 - val_accuracy: 0.5362 - val_loss: 1.5314
# Epoch 30/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 29s 426ms/step - accuracy: 0.5808 - loss: 0.8050 - val_accuracy: 0.6667 - val_loss: 3.3143
# Epoch 31/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 43s 449ms/step - accuracy: 0.6257 - loss: 0.8854 - val_accuracy: 0.6232 - val_loss: 2.4474
# Epoch 32/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 29s 426ms/step - accuracy: 0.6945 - loss: 0.6535 - val_accuracy: 0.6087 - val_loss: 2.1209
# Epoch 33/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 34s 326ms/step - accuracy: 0.7061 - loss: 0.6269 - val_accuracy: 0.6377 - val_loss: 5.5547
# Epoch 34/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 29s 424ms/step - accuracy: 0.6368 - loss: 0.8024 - val_accuracy: 0.4493 - val_loss: 1.1958
# Epoch 35/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 427ms/step - accuracy: 0.5497 - loss: 0.8982 - val_accuracy: 0.4783 - val_loss: 1.2479
# Epoch 36/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 424ms/step - accuracy: 0.4805 - loss: 0.9736 - val_accuracy: 0.5217 - val_loss: 1.5797
# Epoch 37/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 29s 421ms/step - accuracy: 0.5382 - loss: 0.9048 - val_accuracy: 0.5942 - val_loss: 3.0090
# Epoch 38/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 428ms/step - accuracy: 0.6405 - loss: 0.7926 - val_accuracy: 0.5217 - val_loss: 2.1886
# Epoch 39/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 31s 453ms/step - accuracy: 0.6176 - loss: 0.7930 - val_accuracy: 0.5942 - val_loss: 2.5862
# Epoch 40/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 428ms/step - accuracy: 0.6755 - loss: 0.7724 - val_accuracy: 0.3913 - val_loss: 1.0780
# Epoch 41/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 31s 445ms/step - accuracy: 0.3928 - loss: 1.0587 - val_accuracy: 0.4783 - val_loss: 1.0159
# Epoch 42/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 438ms/step - accuracy: 0.5147 - loss: 0.9363 - val_accuracy: 0.4348 - val_loss: 1.0160
# Epoch 43/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 29s 425ms/step - accuracy: 0.4248 - loss: 1.0893 - val_accuracy: 0.3768 - val_loss: 1.0852
# Epoch 44/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 441ms/step - accuracy: 0.3547 - loss: 1.2263 - val_accuracy: 0.4203 - val_loss: 1.0534
# Epoch 45/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 29s 423ms/step - accuracy: 0.3901 - loss: 1.0904 - val_accuracy: 0.4203 - val_loss: 1.0518
# Epoch 46/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 26s 376ms/step - accuracy: 0.4002 - loss: 1.0491 - val_accuracy: 0.4348 - val_loss: 1.0369
# Epoch 47/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 31s 453ms/step - accuracy: 0.4212 - loss: 1.0168 - val_accuracy: 0.4783 - val_loss: 0.9614
# Epoch 48/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 430ms/step - accuracy: 0.5383 - loss: 0.9143 - val_accuracy: 0.5652 - val_loss: 1.3187
# Epoch 49/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 33s 480ms/step - accuracy: 0.5228 - loss: 1.0656 - val_accuracy: 0.4638 - val_loss: 0.9760
# Epoch 50/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 30s 433ms/step - accuracy: 0.5295 - loss: 0.9066 - val_accuracy: 0.4783 - val_loss: 1.0004
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 790ms/step - accuracy: 0.3885 - loss: 1.5608

# %%
X_train_cnn_reshaped = np.expand_dims(X_train, axis=-1)
X_test_cnn_reshaped = np.expand_dims(X_test, axis=-1)

def create_lstm_model(cnn_model):
    # Define the input shape for TimeDistributed layer based on reshaped CNN model output
    input_shape = (SEQUENCE_LENGTH,) + cnn_model.output_shape[1:]
    
    model = Sequential()
    model.add(TimeDistributed(Flatten(input_shape=input_shape)))
    model.add(LSTM(64))
    model.add(Dense(len(CLASSES_LIST), activation='softmax'))
    model.summary()
    return model

lstm_model = create_lstm_model(cnn_model)
# early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10, mode='min', restore_best_weights=True)

# callbacks=[early_stopping_callback]
# Compile and train the LSTM model
lstm_model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=["accuracy"])
lstm_model.fit(X_train_cnn_reshaped, y_train, epochs=50, batch_size=4, shuffle=True, validation_split=0.2)
model_evaluation_history = lstm_model.evaluate(X_test_cnn_reshaped, y_test)
# Calculate additional metrics
y_pred = lstm_model.predict(X_test_cnn_reshaped)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

accuracy = accuracy_score(y_true_classes, y_pred_classes)
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')

# Print the evaluation metrics
print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1-Score: {f1:.4f}')
lstm_model.save('lstm_model.keras')
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ time_distributed_1 (TimeDistributed) │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 14s 129ms/step - accuracy: 0.4715 - loss: 1.5996 - val_accuracy: 0.5217 - val_loss: 1.0574
# Epoch 2/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 118ms/step - accuracy: 0.5223 - loss: 0.9692 - val_accuracy: 0.6232 - val_loss: 0.8748
# Epoch 3/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.6547 - loss: 0.8070 - val_accuracy: 0.6232 - val_loss: 0.8502
# Epoch 4/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.6796 - loss: 0.7816 - val_accuracy: 0.6812 - val_loss: 0.8122
# Epoch 5/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.7120 - loss: 0.7723 - val_accuracy: 0.6957 - val_loss: 0.7617
# Epoch 6/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.7130 - loss: 0.7302 - val_accuracy: 0.6812 - val_loss: 0.8085
# Epoch 7/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 117ms/step - accuracy: 0.7816 - loss: 0.6657 - val_accuracy: 0.6232 - val_loss: 0.7919
# Epoch 8/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 117ms/step - accuracy: 0.7394 - loss: 0.6717 - val_accuracy: 0.7391 - val_loss: 0.7074
# Epoch 9/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.7548 - loss: 0.6404 - val_accuracy: 0.7826 - val_loss: 0.6918
# Epoch 10/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.6897 - loss: 0.6109 - val_accuracy: 0.6957 - val_loss: 0.6975
# Epoch 11/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 10s 116ms/step - accuracy: 0.8230 - loss: 0.5800 - val_accuracy: 0.6957 - val_loss: 0.7255
# Epoch 12/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.7691 - loss: 0.5487 - val_accuracy: 0.7101 - val_loss: 0.6923
# Epoch 13/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.8645 - loss: 0.5101 - val_accuracy: 0.7971 - val_loss: 0.6340
# Epoch 14/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 134ms/step - accuracy: 0.8336 - loss: 0.4645 - val_accuracy: 0.7246 - val_loss: 0.6268
# Epoch 15/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 117ms/step - accuracy: 0.8872 - loss: 0.4482 - val_accuracy: 0.8116 - val_loss: 0.6288
# Epoch 16/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 116ms/step - accuracy: 0.8816 - loss: 0.4615 - val_accuracy: 0.7536 - val_loss: 0.6323
# Epoch 17/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 117ms/step - accuracy: 0.7927 - loss: 0.5318 - val_accuracy: 0.7536 - val_loss: 0.6200
# Epoch 18/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.8804 - loss: 0.4355 - val_accuracy: 0.8406 - val_loss: 0.5330
# Epoch 19/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 117ms/step - accuracy: 0.9435 - loss: 0.3714 - val_accuracy: 0.7971 - val_loss: 0.5759
# Epoch 20/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.8518 - loss: 0.4206 - val_accuracy: 0.8116 - val_loss: 0.5704
# Epoch 21/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 118ms/step - accuracy: 0.9309 - loss: 0.4156 - val_accuracy: 0.8116 - val_loss: 0.5454
# Epoch 22/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.9194 - loss: 0.4329 - val_accuracy: 0.8841 - val_loss: 0.4771
# Epoch 23/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9320 - loss: 0.3467 - val_accuracy: 0.5942 - val_loss: 0.9661
# Epoch 24/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 124ms/step - accuracy: 0.6543 - loss: 0.7984 - val_accuracy: 0.7826 - val_loss: 0.8135
# Epoch 25/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 124ms/step - accuracy: 0.8689 - loss: 0.5237 - val_accuracy: 0.8551 - val_loss: 0.5508
# Epoch 26/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - accuracy: 0.8722 - loss: 0.4110 - val_accuracy: 0.8406 - val_loss: 0.6053
# Epoch 27/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9350 - loss: 0.3877 - val_accuracy: 0.8261 - val_loss: 0.5279
# Epoch 28/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 127ms/step - accuracy: 0.9554 - loss: 0.3742 - val_accuracy: 0.8841 - val_loss: 0.5494
# Epoch 29/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 123ms/step - accuracy: 0.9695 - loss: 0.3345 - val_accuracy: 0.8551 - val_loss: 0.4994
# Epoch 30/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9522 - loss: 0.3209 - val_accuracy: 0.8986 - val_loss: 0.4739
# Epoch 31/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9608 - loss: 0.2927 - val_accuracy: 0.8116 - val_loss: 0.6417
# Epoch 32/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - accuracy: 0.8928 - loss: 0.4422 - val_accuracy: 0.7971 - val_loss: 0.5730
# Epoch 33/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.9533 - loss: 0.3399 - val_accuracy: 0.8406 - val_loss: 0.4698
# Epoch 34/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 10s 118ms/step - accuracy: 0.9918 - loss: 0.2230 - val_accuracy: 0.8551 - val_loss: 0.4485
# Epoch 35/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9480 - loss: 0.2660 - val_accuracy: 0.8986 - val_loss: 0.5406
# Epoch 36/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 122ms/step - accuracy: 0.9610 - loss: 0.3453 - val_accuracy: 0.8841 - val_loss: 0.5126
# Epoch 37/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.9108 - loss: 0.3529 - val_accuracy: 0.8406 - val_loss: 0.5455
# Epoch 38/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 116ms/step - accuracy: 0.9713 - loss: 0.3063 - val_accuracy: 0.8841 - val_loss: 0.4554
# Epoch 39/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9585 - loss: 0.3173 - val_accuracy: 0.8406 - val_loss: 0.5038
# Epoch 40/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9627 - loss: 0.2841 - val_accuracy: 0.8986 - val_loss: 0.4210
# Epoch 41/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9856 - loss: 0.2383 - val_accuracy: 0.8841 - val_loss: 0.4886
# Epoch 42/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9872 - loss: 0.2266 - val_accuracy: 0.8841 - val_loss: 0.4975
# Epoch 43/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 127ms/step - accuracy: 0.9612 - loss: 0.2284 - val_accuracy: 0.8841 - val_loss: 0.4291
# Epoch 44/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9789 - loss: 0.2254 - val_accuracy: 0.8986 - val_loss: 0.4285
# Epoch 45/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9928 - loss: 0.1871 - val_accuracy: 0.8841 - val_loss: 0.4429
# Epoch 46/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.9757 - loss: 0.2235 - val_accuracy: 0.8986 - val_loss: 0.3861
# Epoch 47/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 118ms/step - accuracy: 0.9965 - loss: 0.1797 - val_accuracy: 0.8986 - val_loss: 0.3969
# Epoch 48/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9876 - loss: 0.1876 - val_accuracy: 0.8986 - val_loss: 0.3978
# Epoch 49/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.9904 - loss: 0.1662 - val_accuracy: 0.8986 - val_loss: 0.3882
# Epoch 50/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.9872 - loss: 0.1590 - val_accuracy: 0.8986 - val_loss: 0.3838
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8829 - loss: 0.4261

# %%
def predict_on_video(video_file_path, output_file_path, SEQUENCE_LENGTH):
    '''
    This function will perform action recognition on a video using the LRCN model.
    Args:
    video_file_path:  The path of the video stored in the disk on which the action recognition is to be performed.
    output_file_path: The path where the ouput video with the predicted action being performed overlayed will be stored.
    SEQUENCE_LENGTH:  The fixed number of frames of a video that can be passed to the model as one sequence.
    '''

    # Initialize the VideoCapture object to read from the video file.
    video_reader = cv2.VideoCapture(video_file_path)

    # Get the width and height of the video.
    original_video_width = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))
    original_video_height = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Initialize the VideoWriter Object to store the output video in the disk.
    video_writer = cv2.VideoWriter(output_file_path, cv2.VideoWriter_fourcc('M', 'P', '4', 'V'), 
                                   video_reader.get(cv2.CAP_PROP_FPS), (original_video_width, original_video_height))

    # Declare a queue to store video frames.
    frames_queue = deque(maxlen = SEQUENCE_LENGTH)

    # Initialize a variable to store the predicted action being performed in the video.
    predicted_class_name = ''

    # Iterate until the video is accessed successfully.
    while video_reader.isOpened():

        # Read the frame.
        ok, frame = video_reader.read() 
        
        # Check if frame is not read properly then break the loop.
        if not ok:
            break

        # Resize the Frame to fixed Dimensions.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1.
        normalized_frame = resized_frame / 255

        # Appending the pre-processed frame into the frames list.
        frames_queue.append(normalized_frame)

        # Check if the number of frames in the queue are equal to the fixed sequence length.
        if len(frames_queue) == SEQUENCE_LENGTH:

            # Pass the normalized frames to the model and get the predicted probabilities.
            predicted_labels_probabilities = lstm_model.predict(np.expand_dims(frames_queue, axis = 0))[0]

            # Get the index of class with highest probability.
            predicted_label = np.argmax(predicted_labels_probabilities)

            # Get the class name using the retrieved index.
            predicted_class_name = CLASSES_LIST[predicted_label]

        # Write predicted class name on top of the frame.
        cv2.putText(frame, predicted_class_name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

        # Write The frame into the disk using the VideoWriter Object.
        video_writer.write(frame)
        
    # Release the VideoCapture and VideoWriter objects.
    video_reader.release()
    video_writer.release()

# %%
# Construct the output video path.
output_video_file_path = r"C:\Users\dines\Downloads\bikingl.mp4"
input_video_file_path = r"C:\Users\dines\Downloads\biking.mp4"
# Perform Action Recognition on the Test Video.
predict_on_video(input_video_file_path, output_video_file_path, SEQUENCE_LENGTH)

# Display the output video.
VideoFileClip(output_video_file_path, audio=False, target_resolution=(300,None)).ipython_display()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
